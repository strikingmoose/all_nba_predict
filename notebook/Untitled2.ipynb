# %%
import pandas as pd

testTable = pd.read_html(
    io = r'https://en.wikipedia.org/wiki/NBA_All-Star_Game',
    attrs = {'class': 'wikitable'}
)

print len(testTable)
# Out:
# 2

# %%
testTable[0]
# Out:
#                               0                             1
# 0  Eastern Conference (37 wins)  Western Conference (29 wins)

# %%
testTable[1]
# Out:
#        0                                                  1  \
# 0   Year                                             Result
# 1   1951                                  East 111, West 94
# 2   1952                                  East 108, West 91
# 3   1953                                   West 79, East 75
# 4   1954                              East 98, West 93 (OT)
# 5   1955                                  East 100, West 91
# 6   1956                                  West 108, East 94
# 7   1957                                  East 109, West 97
# 8   1958                                 East 130, West 118
# 9   1959                                 West 124, East 108
# 10  1960                                 East 125, West 115
# 11  1961                                 West 153, East 131
# 12  1962                                 West 150, East 130
# 13  1963                                 East 115, West 108
# 14  1964                                 East 111, West 107
# ...

# %%
testTable[1].columns = ['Year', 'Result', 'Host Arena', '', '']

# %%
testTable[1]
# Out:
#     Year                                             Result  \
# 0   Year                                             Result
# 1   1951                                  East 111, West 94
# 2   1952                                  East 108, West 91
# 3   1953                                   West 79, East 75
# 4   1954                              East 98, West 93 (OT)
# 5   1955                                  East 100, West 91
# 6   1956                                  West 108, East 94
# 7   1957                                  East 109, West 97
# 8   1958                                 East 130, West 118
# 9   1959                                 West 124, East 108
# 10  1960                                 East 125, West 115
# 11  1961                                 West 153, East 131
# 12  1962                                 West 150, East 130
# 13  1963                                 East 115, West 108
# 14  1964                                 East 111, West 107
# ...
